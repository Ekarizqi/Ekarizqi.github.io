# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('datd_test.csv')
data
# Out:
#                                                   text  label
# 0    ngga enak bgt akhir2 ini rasanya, sering cemas...      1
# 1                      Sedikit khawatir dan gelisah. 😓      1
# 2    Ngelakuin kesalahan yang sama. Bodoh bgt. Udah...      1
# 3          Pantesan gelisah bae, lupa lgi ga ada duit🤭      0
# 4    Semoga Mei disertai kabar-kabar baik. Yang luk...      0
# ..                                                 ...    ...
# 545                     gelisah, padahal gitu doang bd      1
# 546  Kekhawatiran berlebih akan membuat stress, ngg...      0
# 547  otak gue kalo malem gini suka kemana mana hera...      1
# 548  Kalo lg gelisah beban banyak pikiran trs langs...      0
# 549  Astagfirullah....Astagfirullah....Astagfirulla...      0
#
# [550 rows x 2 columns]

# %% [markdown]
# #data cleaning
# import re
# def cleaning(str):
#   #remove space yang berlebih
#  str= re.sub('\s+',"", str)
#
#   #membuang selain huruf
#  str = re.sub("[^a-zA-Z]+", "", str)
#
#  #remove url
#  str = re.sub(r"https?://\S+|www\.\S+","", str)
#
#  #remove email
#  str = re.sub("[\w\.-]+@[\w\.-]+\.\w+", "", str)
#
#  #remove hashtag
#  str = re.sub("#[_]*[a-z]+", "", str)
#
#  #remove mention
#  str = re.sub("@\S+", "" ,str)
#
#  return str

# %%
# data cleaning
import re

def deEmojify(text):
    regrex_pattern = re.compile(pattern = "["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"
        u"\U0001F700-\U0001F77F"  # alchemical symbols
        u"\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
        u"\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
        u"\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
        u"\U0001FA00-\U0001FA6F"  # Chess Symbols
        u"\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
        u"\U00002702-\U000027B0"  # Dingbats
        u"\U000024C2-\U0001F251"# flags (iOS)
                           "]+", flags = re.UNICODE)
    return regrex_pattern.sub(r'',text)

def process(text):
    # remove links
    text = re.sub("https://t.co/\S*","",text)

    # remove newline
    text = re.sub("\n","",text)

    # remove digits
    text = re.sub("[0-9]","",text)

    # remove emojis
    text = deEmojify(text)

    #membuang selain huruf
    text = re.sub("[^a-zA-Z ]+", " ", text)

    #lowercase
    text= text.lower()

    return text

# %%
data['clean_text'] = data.text.apply(process)

# %%
data
# Out:
#                                                   text  label  \
# 0    ngga enak bgt akhir2 ini rasanya, sering cemas...      1
# 1                      Sedikit khawatir dan gelisah. 😓      1
# 2    Ngelakuin kesalahan yang sama. Bodoh bgt. Udah...      1
# 3          Pantesan gelisah bae, lupa lgi ga ada duit🤭      0
# 4    Semoga Mei disertai kabar-kabar baik. Yang luk...      0
# ..                                                 ...    ...
# 545                     gelisah, padahal gitu doang bd      1
# 546  Kekhawatiran berlebih akan membuat stress, ngg...      0
# 547  otak gue kalo malem gini suka kemana mana hera...      1
# 548  Kalo lg gelisah beban banyak pikiran trs langs...      0
# 549  Astagfirullah....Astagfirullah....Astagfirulla...      0
#
#                                             clean_text
# 0    ngga enak bgt akhir ini rasanya  sering cemas ...
# 1                       sedikit khawatir dan gelisah
# 2    ngelakuin kesalahan yang sama  bodoh bgt  udah...
# ...

# %%
data2 = data[["clean_text", "label"]]
data2
# Out:
#                                             clean_text  label
# 0    ngga enak bgt akhir ini rasanya  sering cemas ...      1
# 1                       sedikit khawatir dan gelisah        1
# 2    ngelakuin kesalahan yang sama  bodoh bgt  udah...      1
# 3           pantesan gelisah bae  lupa lgi ga ada duit      0
# 4    semoga mei disertai kabar kabar baik  yang luk...      0
# ..                                                 ...    ...
# 545                     gelisah  padahal gitu doang bd      1
# 546  kekhawatiran berlebih akan membuat stress  ngg...      0
# 547  otak gue kalo malem gini suka kemana mana hera...      1
# 548  kalo lg gelisah beban banyak pikiran trs langs...      0
# 549  astagfirullah astagfirullah astagfirullah ngan...      0
#
# [550 rows x 2 columns]

# %%
data2.to_csv("data2_clean.csv", index=False)

# %%
data = pd.read_csv("data2_clean.csv")
data
# Out:
#                                             clean_text  label
# 0    ngga enak bgt akhir ini rasanya  sering cemas ...      1
# 1                       sedikit khawatir dan gelisah        1
# 2    ngelakuin kesalahan yang sama  bodoh bgt  udah...      1
# 3           pantesan gelisah bae  lupa lgi ga ada duit      0
# 4    semoga mei disertai kabar kabar baik  yang luk...      0
# ..                                                 ...    ...
# 545                     gelisah  padahal gitu doang bd      1
# 546  kekhawatiran berlebih akan membuat stress  ngg...      0
# 547  otak gue kalo malem gini suka kemana mana hera...      1
# 548  kalo lg gelisah beban banyak pikiran trs langs...      0
# 549  astagfirullah astagfirullah astagfirullah ngan...      0
#
# [550 rows x 2 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   clean_text  550 non-null    object
#  1   label       550 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 8.7+ KB

# %% [markdown]
# tokenisasi menggunakan split

# %%
# def split(clean_text):
#   clean_text = clean_text.split()
#   return clean_text

# %%
# data['token_text'] = data.clean_text.apply(split)
# data

# %%
# data_tokenisasi= data["token_text"]

# %%
# data_tokenisasi.to_csv("data_tokenisasi.csv", index = False)

# %% [markdown]
# tokenisasi menggunakan modul NLTK

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
def word_tokenization(clean_text):
  clean_text = word_tokenize(clean_text)
  return clean_text

# %%
data['token_text'] = data.clean_text.apply(word_tokenization)
data
# Out:
#                                             clean_text  label  \
# 0    ngga enak bgt akhir ini rasanya  sering cemas ...      1
# 1                       sedikit khawatir dan gelisah        1
# 2    ngelakuin kesalahan yang sama  bodoh bgt  udah...      1
# 3           pantesan gelisah bae  lupa lgi ga ada duit      0
# 4    semoga mei disertai kabar kabar baik  yang luk...      0
# ..                                                 ...    ...
# 545                     gelisah  padahal gitu doang bd      1
# 546  kekhawatiran berlebih akan membuat stress  ngg...      0
# 547  otak gue kalo malem gini suka kemana mana hera...      1
# 548  kalo lg gelisah beban banyak pikiran trs langs...      0
# 549  astagfirullah astagfirullah astagfirullah ngan...      0
#
#                                             token_text
# 0    [ngga, enak, bgt, akhir, ini, rasanya, sering,...
# 1                    [sedikit, khawatir, dan, gelisah]
# ...

# %%
token_nltk = data.drop(['clean_text'], axis=1)
token_nltk
# Out:
#      label                                         token_text
# 0        1  [ngga, enak, bgt, akhir, ini, rasanya, sering,...
# 1        1                  [sedikit, khawatir, dan, gelisah]
# 2        1  [ngelakuin, kesalahan, yang, sama, bodoh, bgt,...
# 3        0  [pantesan, gelisah, bae, lupa, lgi, ga, ada, d...
# 4        0  [semoga, mei, disertai, kabar, kabar, baik, ya...
# ..     ...                                                ...
# 545      1                [gelisah, padahal, gitu, doang, bd]
# 546      0  [kekhawatiran, berlebih, akan, membuat, stress...
# 547      1  [otak, gue, kalo, malem, gini, suka, kemana, m...
# 548      0  [kalo, lg, gelisah, beban, banyak, pikiran, tr...
# 549      0  [astagfirullah, astagfirullah, astagfirullah, ...
#
# [550 rows x 2 columns]

# %%
token_nltk.to_csv("token_nltk.csv", index=False)

# %%
dataset = pd.read_csv("token_nltk.csv")
dataset
# Out:
#      label                                         token_text
# 0        1  ['ngga', 'enak', 'bgt', 'akhir', 'ini', 'rasan...
# 1        1          ['sedikit', 'khawatir', 'dan', 'gelisah']
# 2        1  ['ngelakuin', 'kesalahan', 'yang', 'sama', 'bo...
# 3        0  ['pantesan', 'gelisah', 'bae', 'lupa', 'lgi', ...
# 4        0  ['semoga', 'mei', 'disertai', 'kabar', 'kabar'...
# ..     ...                                                ...
# 545      1      ['gelisah', 'padahal', 'gitu', 'doang', 'bd']
# 546      0  ['kekhawatiran', 'berlebih', 'akan', 'membuat'...
# 547      1  ['otak', 'gue', 'kalo', 'malem', 'gini', 'suka...
# 548      0  ['kalo', 'lg', 'gelisah', 'beban', 'banyak', '...
# 549      0  ['astagfirullah', 'astagfirullah', 'astagfirul...
#
# [550 rows x 2 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   label       550 non-null    int64
#  1   token_text  550 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 8.7+ KB

# %% [markdown]
# frekuensi kemunculan kata

# %%
pip install sastrawi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 5.1 MB/s eta 0:00:00
# ...

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# %%
def stemming(token_text):
  factory = StemmerFactory()
  stemmer = factory.create_stemmer()
  return stemmer.stem(token_text)

# %%
data['stemming_text'] = dataset.token_text.apply(stemming)
data
# Out:
#                                             clean_text  label  \
# 0    ngga enak bgt akhir ini rasanya  sering cemas ...      1
# 1                       sedikit khawatir dan gelisah        1
# 2    ngelakuin kesalahan yang sama  bodoh bgt  udah...      1
# 3           pantesan gelisah bae  lupa lgi ga ada duit      0
# 4    semoga mei disertai kabar kabar baik  yang luk...      0
# ..                                                 ...    ...
# 545                     gelisah  padahal gitu doang bd      1
# 546  kekhawatiran berlebih akan membuat stress  ngg...      0
# 547  otak gue kalo malem gini suka kemana mana hera...      1
# 548  kalo lg gelisah beban banyak pikiran trs langs...      0
# 549  astagfirullah astagfirullah astagfirullah ngan...      0
#
#                                             token_text  \
# 0    [ngga, enak, bgt, akhir, ini, rasanya, sering,...
# 1                    [sedikit, khawatir, dan, gelisah]
# ...

# %%
# from nltk.probability import FreqDist

# %%
# def frekuensi_kata(token_text):
#   token_text = FreqDist(token_text)
#   return token_text

# %%
# data['frekuensi'] = token_nltk.token_text.apply(frekuensi_kata)
# print(data['frekuensi'])
